# %% [markdown]
# <a href="https://colab.research.google.com/github/jiho25-hl/ABCD-A/blob/20250310/20250310.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
watch = 10000
print(watch)
# Out:
# 10000

# %%
a = 'pig'
b = 'dad'
print(a)
print(b)
print(watch)
print(a+b)
print(a+' '+b)
# Out:
# pig
# dad
# 10000
# pigdad
# pig dad

# %%
a = 10
a,b = (10,20)
[a,b] = [10,20]
a = b = 10
a = None

# %%
a = 10
b = 2000
a,b = b,a

# %%
a = [10,20,30]

# %%
a = [10,20,30]
b = a

# %%
a = [10,20,30]
b = a

a = [10,20,30]
b = a
a[0] = 200
print(b)
# Out:
# [200, 20, 30]

# %%
# 예제입니다.
a = [10,20,30]
b = a
a[0] = 200
print(b)
# Out:
# [200, 20, 30]

# %%
print("Hello world")
print(1)
a = 1
print(a)
# Out:
# Hello world
# 1
# 1

# %%
print("a =" +str(a))
print("a =", a)
print("a =".format(a))
# Out:
# a =1
# a = 1
# a =

# %%
#day1 프로그램
a = [10,20,30]
b = 1
c = 2
print (a)
print("a ={}".format(a))
print("b ={}".format(b))
print("a ={}".format(a,b,c))
# Out:
# [10, 20, 30]
# a =[10, 20, 30]
# b =1
# a =[10, 20, 30]

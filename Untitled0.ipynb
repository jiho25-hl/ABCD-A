# %% [markdown]
# <a href="https://colab.research.google.com/github/jiho25-hl/ABCD-A/blob/20250326/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
삼성전자=50000
총평가금액=삼성전자*10
print(총평가금액)
# Out:
# 500000

# %%
시가총액=2980000000000
현재가=50000
per=15.79
print(시가총액,type(시가총액))
print(현재가,type(현재가))
print(per,type(per))
# Out:
# 2980000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
s="hello!"
t="python"
print (s+t)
# Out:
# hello!python

# %%
x=2
y=3
print(x*y+x)
# Out:
# 8
